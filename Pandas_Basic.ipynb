# %%
import pandas as pd
df= pd.read_csv('/content/nba.csv')
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# ** Shape() is use for no of rows and coloums.***

# %%
df.shape # Finding the no of rows and coloumns.
# Out:
# (458, 9)

# %%
df.head(5)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df.tail(5)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
import pandas as pd
data=pd.read_csv(r"/content/nba.csv")
data =pd.Series(data.Age) # series
#data =pd.DataFrame(data)   # Datafram
data
# Out:
# 0      25.0
# 1      25.0
# 2      27.0
# 3      22.0
# 4      29.0
#        ...
# 453    26.0
# 454    24.0
# 455    26.0
# 456    26.0
# 457     NaN
# Name: Age, Length: 458, dtype: float64

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
print(r'hll\noo')
# Out:
# hll\noo

# %% [markdown]
# +***List**
#
# 1. Lists are used to store multiple items in a single variable.
# 2. Lists are created using square brackets:[]
# 3. List items are ordered, changeable, and allow duplicate values.

# %% [markdown]
# ***Series**  1D Column

# %%
newlst  =["a","b","c"]
print(newlst)
# Out:
# ['a', 'b', 'c']

# %%
import pandas as pd

# %%
import pandas as pd
lst =["pune","nashik","surat","goa"]
print(lst)
newlist =pd.Series(lst)
print(newlist)
# Out:
# ['pune', 'nashik', 'surat', 'goa']
# 0      pune
# 1    nashik
# 2     surat
# 3       goa
# dtype: object

# %%
newlist =pd.DataFrame(lst)
print(newlist)
# Out:
#         0
# 0    pune
# 1  nashik
# 2   surat
# 3     goa

# %%
print(newlist[:2]) # slicing
# Out:
#         0
# 0    pune
# 1  nashik

# %% [markdown]
# ***DataFrame** 2d ,
# column and rows

# %%
import pandas as pd

list1 =[1,2,3]
newlist= pd.DataFrame(list1,index=[1,2,3], dtype=float)

print(newlist)
# Out:
#      0
# 1  1.0
# 2  2.0
# 3  3.0

# %%
newlist = list1.index(1)
newlist
# Out:
# 0

# %% [markdown]
# ***Slicing**

# %%
print(newlist[:2])
# Out:
#      0
# 1  1.0
# 2  2.0

# %%
lis

# %%
a= ["a","b","c"]
ab =a.index('a')
print(ab)
# Out:
# 0

# %%
ls =pd.DataFrame(lst)
print(ls)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %% [markdown]
# ***Tuple***
#
# * Tuples are used to store multiple items in a single variable.
# * Tuples are written with round brackets.
# * Tuple items are ordered, unchangeable, and allow duplicate values.

# %%
a=("a","b","c")
myval =pd.series(a,index=["a","b"])
# Out:
# ('a', 'b', 'c')

# %%
import pandas as pd

a = [1, 7, 2]

myvar = pd.Series(a, index = ["x", "y", "z"])

print(myvar["y"])
# Out:
# 7

# %% [markdown]
# ***Tuple**

# %%
studentlst =("a","b","c") #studentlst
print(type(studentlst))
# Out:
# <class 'tuple'>

# %%
dict = {'name':'priya',
'rollno':'suraj'}

print(type(dict))
# Out:
# <class 'dict'>

# %%
dict1 ={'name':['abc','baba'],
        'salary':[5,4]}
print(type(dict1))
# Out:
# <class 'dict'>

# %%
import pandas as pd
data = {'Name':['Tom', 'nick', 'krish', 'jack'],
        'Age':[20, 21, 19, 18]}
df= pd.DataFrame(data)
print(df)
# Out:
#     Name  Age
# 0    Tom   20
# 1   nick   21
# 2  krish   19
# 3   jack   18

# %%
import pandas as pd
df = pd.read_csv("/content/nba.csv")
print(df)
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.shape
# Out:
# (458, 9)

# %%
df.head()

# %%
import pandas as pd
df =pd.read_csv('/content/nba.csv',index_col="Name")
print(df)
# retrieving row by loc method
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ...                       ...     ...      ...   ...    ...     ...
# Shelvin Mack        Utah Jazz     8.0       PG  26.0    6-3   203.0
# Raul Neto           Utah Jazz    25.0       PG  24.0    6-1   179.0
# Tibor Pleiss        Utah Jazz    21.0        C  26.0    7-3   256.0
# Jeff Withey         Utah Jazz    24.0        C  26.0    7-0   231.0
# NaN                       NaN     NaN      NaN   NaN    NaN     NaN
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# ...

# %% [markdown]
# ***Indexing a DataFrame using .iloc[ ] :
# This function allows us to retrieve rows and columns by position. In order to do that, we’ll need to specify the positions of the rows that we want, and the positions of the columns that we want as well. The df.iloc indexer is very similar to df.loc but only uses integer locations to make its selections.***

# %%
first = df.loc["Avery Bradley"]
second = df.loc["Jeff Withey"]


print(first, "\n\n\n", second)
# Out:
# Team        Boston Celtics
# Number                 0.0
# Position                PG
# Age                   25.0
# Height                 6-2
# Weight               180.0
# College              Texas
# Salary           7730337.0
# Name: Avery Bradley, dtype: object
#
#
#  Team        Utah Jazz
# Number           24.0
# Position            C
# Age              26.0
# Height            7-0
# Weight          231.0
# College        Kansas
# Salary       947276.0
# Name: Jeff Withey, dtype: object

# %% [markdown]
# ***Selecting a single columns
# In order to select a single column, we simply put the name of the column in-between the brackets***

# %%
first= df['Team']
print(first)
# Out:
# Name
# Avery Bradley    Boston Celtics
# Jae Crowder      Boston Celtics
# John Holland     Boston Celtics
# R.J. Hunter      Boston Celtics
# Jonas Jerebko    Boston Celtics
#                       ...
# Shelvin Mack          Utah Jazz
# Raul Neto             Utah Jazz
# Tibor Pleiss          Utah Jazz
# Jeff Withey           Utah Jazz
# NaN                         NaN
# Name: Team, Length: 458, dtype: object

# %%
# retrieving rows by iloc method
row2 = df.iloc[3]
print(row2)
# Out:
# Team        Boston Celtics
# Number                28.0
# Position                SG
# Age                   22.0
# Height                 6-5
# Weight               185.0
# College      Georgia State
# Salary           1148640.0
# Name: R.J. Hunter, dtype: object

# %% [markdown]
# ***loc get rows and coloum uisng lable**

# %%
df.loc[:'R.J. Hunter']
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# John Holland   Boston University        NaN
# R.J. Hunter        Georgia State  1148640.0

# %% [markdown]
# ***iloc get rows and coloum  using index number***

# %%
df.iloc[:5]
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df= pd.read_csv('/content/nba.csv')
df.head(10)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9   Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# ...

# %%
ser = pd.Series(df['Name'])
ser.head(5)
print(ser,"\n")
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# 457              NaN
# Name: Name, Length: 458, dtype: object

# %%
before = df.dtypes
print("before conversion:", before, "\n")
# Out:
# before conversion: Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
data = df.drop_duplicates()
print(df)
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
data.dropna(inplace = True)


# converting dtypes using astype
data["Salary"]= data["Salary"].astype(int)
data["Number"]= data["Number"].astype(str)

# storing dtype after converting
after = data.dtypes

# printing to compare
# printing to compare
print("AFTER CONVERSION\n", after, "\n")
# Out:
# AFTER CONVERSION
#  Name         object
# Team         object
# Number       object
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary        int64
# dtype: object

# %%
a = 10
print(a)
print(type(a))
# Out:
# 10
# <class 'int'>

# %%
print("hello")
# Out:
# hello
